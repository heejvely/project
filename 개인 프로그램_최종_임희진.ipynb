# %%
class Menu():
    def korean(self):
        car1 = 254 ; pro1 = 128 ; fat1 = 167
        car2 = 258 ; pro2 = 214 ; fat2 = 113
        car3 = 276 ; pro3 = 97 ; fat3 = 92
        car4 = 314 ; pro4 = 260 ; fat4 = 154
        car5 = 164 ; pro5 = 462 ; fat5 = 290
        
        self.kor1 = f'''
> 1. 현미밥, 데친 두부, 김치국, 계란말이, 배추김치
--------------------------------------------------------------------
총 칼로리: [{car1+pro1+fat1}kcal] 탄수화물: [{car1}kcal] 단백질: [{pro1}kcal] 지방: [{fat1}kcal]\n\n'''

        self.kor2 = f'''
> 2. 쌀밥, 갈치구이, 콩조림, 동치미
--------------------------------------------------------------------
총 칼로리: [{car2+pro2+fat2}kcal] 탄수화물: [{car2}kcal] 단백질: [{pro2}kcal] 지방: [{fat2}kcal]\n\n'''
        self.kor3 = f'''
> 3. 검정콩밥, 돼지갈비찜, 된장찌개, 배추김치
--------------------------------------------------------------------
총 칼로리: [{car3+pro3+fat3}kcal] 탄수화물: [{car3}kcal] 단백질: [{pro3}kcal] 지방: [{fat3}kcal]\n\n'''
        self.kor4 = f'''
> 4. 현미밥, 김치국, 데친 두부, 갈치 구이, 콩조림, 배추김치
--------------------------------------------------------------------
총 칼로리: [{car4+pro4+fat4}kcal] 탄수화물: [{car4}kcal] 단백질: [{pro4}kcal] 지방: [{fat4}kcal]\n\n'''
        self.kor5 = f'''
> 5. 삼계탕, 배추김치
--------------------------------------------------------------------
총 칼로리: [{car5+pro5+fat5}kcal] 탄수화물: [{car5}kcal] 단백질: [{pro5}kcal] 지방: [{fat5}kcal]\n\n'''

        print(self.kor1)
        time.sleep(1)
        print(self.kor2)
        time.sleep(1)
        print(self.kor3)
        time.sleep(1)
        print(self.kor4)
        time.sleep(1)
        print(self.kor5)

    def western(self):
        car1 = 194 ;pro1 = 103 ; fat1 = 76
        car2 = 150 ; pro2 = 114 ; fat2 = 27
        car3 = 336 ; pro3 = 101 ; fat3 = 194
        car4 = 502 ; pro4 = 78 ; fat4 = 162
        car5 = 99 ; pro5 = 305 ; fat5 = 197
        self.wes1 = f'''
> 6. 호밀식빵 2조각, 삶은 달걀 2개, 가든 샐러드, 소세지 2개
--------------------------------------------------------------------
총 칼로리: [{car1+pro1+fat1}kcal] 탄수화물: [{car1}kcal] 단백질: [{pro1}kcal] 지방: [{fat1}kcal]\n\n'''
        self.wes2 = f'''
> 7. 연어 구이, 찐감자, 데친 아스파라거스, 새송이버섯구이
--------------------------------------------------------------------
총 칼로리: [{car2+pro2+fat2}kcal] 탄수화물: [{car2}kcal] 단백질: [{pro2}kcal] 지방: [{fat2}kcal]\n\n'''
        self.wes3 = f'''
> 8. 훈제연어와 크림치즈 베이글 샌드, 단호박스프, 가든 샐러드, 바나나 1개
--------------------------------------------------------------------
총 칼로리: [{car3+pro3+fat3}kcal] 탄수화물: [{car3}kcal] 단백질: [{pro3}kcal] 지방: [{fat3}kcal]\n\n'''
        self.wes4 = f'''
> 9. 팬케이크, 달걀프라이, 콘 샐러드, 바나나 1개
--------------------------------------------------------------------
총 칼로리: [{car4+pro4+fat4}kcal] 탄수화물: [{car4}kcal] 단백질: [{pro4}kcal] 지방: [{fat4}kcal]\n\n'''
        self.wes5 = f'''
> 10. 안심 스테이크, 머쉬룸스프, 자몽 샐러드, 데친 당근, 데친 브로콜리
--------------------------------------------------------------------
총 칼로리: [{car5+pro5+fat5}kcal] 탄수화물: [{car5}kcal] 단백질: [{pro5}kcal] 지방: [{fat5}kcal]\n\n'''

        print(self.wes1)
        time.sleep(1)
        print(self.wes2)
        time.sleep(1)
        print(self.wes3)
        time.sleep(1)
        print(self.wes4)
        time.sleep(1)
        print(self.wes5)

    def japanese(self):
        car1 = 320 ;pro1 = 84 ; fat1 = 53
        car2 = 268 ; pro2 = 164 ; fat2 = 87
        car3 = 232 ; pro3 = 219 ; fat3 = 333
        car4 = 276 ; pro4 = 112 ; fat4 = 38
        self.jap1 = f'''
> 11. 모듬 초밥(12piece)
--------------------------------------------------------------------
총 칼로리: [{car1+pro1+fat1}kcal] 탄수화물: [{car1}kcal] 단백질: [{pro1}kcal] 지방: [{fat1}kcal]\n\n'''
        self.jap2 = f'''
> 12. 쇠고기 샤브샤브, 우동사리
--------------------------------------------------------------------
총 칼로리: [{car2+pro2+fat2}kcal] 탄수화물: [{car2}kcal] 단백질: [{pro2}kcal] 지방: [{fat2}kcal]\n\n'''
        self.jap3 = f'''
> 13. 쌀밥, 고등어구이(1/2 piece), 붕장어 소금구이(1/2 piece), 미소 된장국
--------------------------------------------------------------------
총 칼로리: [{car3+pro3+fat3}kcal] 탄수화물: [{car3}kcal] 단백질: [{pro3}kcal] 지방: [{fat3}kcal]\n\n'''
        self.jap4 = f'''
> 14. 쌀밥, 연어회, 양파, 미소 된장국, 배추 김치
--------------------------------------------------------------------
총 칼로리: [{car4+pro4+fat4}kcal] 탄수화물: [{car4}kcal] 단백질: [{pro4}kcal] 지방: [{fat4}kcal]\n\n'''
        
        print(self.jap1)
        time.sleep(1)
        print(self.jap2)
        time.sleep(1)
        print(self.jap3)
        time.sleep(1)
        print(self.jap4)

# %%
import time
class Recomendation(Menu):
    def __init__(self):
        print('사용하시는 분의 정보를 입력해주세요.')
        
    def person(self):
        while True:
            name = input('성함을 입력해주세요. ')

    #def 기초대사량(self):
            while True:
                try:
                    age = int(input('나이를 입력해주세요. '))
                    height = int(input('키를 입력해주세요. <cm 단위> '))
                    kg = int(input('몸무게를 입력해주세요.<소수점 제외> '))
                    sex = input('성별을 입력해주세요. <여자 or 남자> ')
                    basic_w = round((65.51 + (9.56*kg) + (1.85*height) - (4.68*age)),0)
                    basic_m = round((66.47 + (13.75*kg) + (5*height) - (6.76*age)),0)
                    print()
                    print('{}님께서 입력해주신 정보는 아래와 같습니다.'.format(name))
                    print()
                    time.sleep(1)
                    print('| 이름: {}님\n| 키: {}cm\n| 몸무게: {}kg\n| 성별: {} '.format(name,height,kg,sex))
                    time.sleep(1)
                    right = int(input('\n맞으면 1 입력, 다시 입력하시려면 2를 입력해주세요.\n입력한 정보가 맞으면 기초대사량을 알려드립니다.'))
                except Exception:
                    print('다시 입력해주세요.')
                    continue
                if right ==1:
                    pass
                elif right ==2:
                    continue
                else:
                    print('1 or 2 다시 입력해주세요.')
                    continue
                    
                if sex == '여자':
                    time.sleep(1)
                    print('\n{}님의 기초 대사량은 {}kcal입니다.'.format(name,basic_w))
                    print()
                elif sex == '남자':
                    time.sleep(1)
                    print('\n{}님의 기초 대사량은 {}kcal입니다.'.format(name,basic_m))
                    print()
                else:
                    print('다시 입력해주세요.')
                    continue
                
             
                while True:
                    try:
                        time.sleep(1)
                        활동지수 = int(input('*활동량이 적으면: 1 입력\n*활동량이 보통이면: 2 입력\n*활동량이 많으면: 3 입력  '))
                        basic = (height - 100) * 0.9
                    except:
                        print('다시 입력해주세요.')
                        continue

                    if 활동지수 == 1:
                        if kg > 60:
                            a = int(basic*25)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()
                        else:
                            a = int(basic*25-200)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()

                    elif 활동지수 == 2:
                        if kg > 60:
                            a = int(basic*30)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()
                        else:
                            a = int(basic*30-200)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()
                    elif 활동지수 == 3:
                        if kg > 60:
                            a = int(basic*40)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()
                        else:
                            a = int(basic*40-200)
                            time.sleep(1)
                            print('{}님은 하루 {}kcal를 섭취해야 합니다.'.format(name,a))
                            print()
                    else:
                        print('다시 입력해주세요.')
                        continue
                    

                    while True:
                        #def 탄단지(self,height):
                        try:
                            time.sleep(1)
                            diet =  int(input('다이어트 중이신가요? <y: 1 입력 or n: 2 입력> '))
                            bcar = round(a*0.5);bpro = round(a*0.3);bfat = round(a*0.2)
                            b_diet = '탄수화물: {}kcal, 단백질: {}kcal 지방: {}kcal'.format(bcar,bpro,bfat)
                            n_diet = '탄수화물: {}kcal, 단백질: {}kcal 지방: {}kcal'.format(bcar,bpro,bfat)
                        except:
                            print('1(y) or 2(n)으로 다시 입력해 주십시오.')
                            continue

                        if diet == 1:
                            time.sleep(1)
                            print('다이어트 중이시면 {}를 섭취해야 합니다.'.format(b_diet))
                            print()
                        elif diet == 2:
                            time.sleep(1)
                            print('다이어트 중이 아니시면 {}를 섭취해야 합니다.'.format(n_diet))
                            print()
                        

                        while True:
                        #def 식단추천(self,name):
                            try:
                                time.sleep(1)
                                print('메뉴를 추천해드리겠습니다.')
                                끼니 = int(input('평소 몇 끼니를 드시나요? <2끼: 1 입력, 3끼: 2 입력>'))
                            except:
                                print('1(2끼) or 2(3끼)를 입력해 주십시오.')
                                continue
                            if 끼니 == 1:
                                time.sleep(1)
                                print(f'{name}님의 1끼 식사별 적정 kcal을 안내 해드립니다.\n|총 kcal:{a/2}kcal\n|탄수화물: {a/2*0.5}kcal\n|단백질: {a/2*0.3}kcal\n|지방: {a/2*0.2}kcal ')
                                for i in range(2):
                                    while True:
                                        try:
                                            time.sleep(1)
                                            menu = input('원하시는 종류를 선택해주세요. <한식: 1 입력, 양식: 2 입력, 일식: 3 입력>')
                                            time.sleep(1)
                                        except:
                                            print('1(한식) or 2(양식) or 3(일식) 으로 다시 입력해 주십시오.')
                                            return
                                        if menu == '1':
                                            self.korean()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 1:
                                                print(self.kor1+'를 선택하셨습니다.')
                                            elif num == 2:
                                                print(self.kor2+'를 선택하셨습니다.')
                                            elif num ==3:
                                                print(self.kor3+'를 선택하셨습니다.')
                                            elif num ==4:
                                                print(self.kor4+'를 선택하셨습니다.')
                                            elif num == 5:
                                                print(self.kor5+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        elif menu == '2':
                                            self.western()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 6:
                                                print(self.wes1+'를 선택하셨습니다.')
                                            elif num == 7:
                                                print(self.wes2+'를 선택하셨습니다.')
                                            elif num ==8:
                                                print(self.wes3+'를 선택하셨습니다.')
                                            elif num ==9:
                                                print(self.wes4+'를 선택하셨습니다.')
                                            elif num == 10:
                                                print(self.wes5+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        elif menu == '3':
                                            self.japanese()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 11:
                                                print(self.jap1+'를 선택하셨습니다.')
                                            elif num == 12:
                                                print(self.jap2+'를 선택하셨습니다.')
                                            elif num ==13:
                                                print(self.jap3+'를 선택하셨습니다.')
                                            elif num ==14:
                                                print(self.jap4+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        else:
                                            print('1(한식) or 2(양식) or 3(일식) 으로 다시 입력해 주십시오.')

                                    if i == 0:
                                        filename = '칼로리표.csv'
                                        with open(filename,'r') as f:
                                            kcal_list = []
                                            while True:
                                                data = f.readline()
                                                if not data:
                                                    break
                                                div = data.split(',')
                                                if div[0] == '{}'.format(num):
                                                    kcal_list.append(div)
                                            time.sleep(1)
                                            i1 = int(a - int(kcal_list[0][1]));i2 = int(bcar - int(kcal_list[0][2]));i3 = int(bpro - int(kcal_list[0][3]));i4 = int(bfat - int(kcal_list[0][4]))
                                            print(f'\n|총 kcal: [{i1}kcal]\n|탄수화물: [{i2}kcal]\n|단백질: [{i3}kcal]\n|지방: [{i4}kcal]\n를 더 섭취하셔야 합니다.\n')

                                    elif i == 1:
                                        with open(filename,'r') as f:
                                            kcal_list = []
                                            while True:
                                                data = f.readline()
                                                if not data:
                                                    break
                                                div = data.split(',')
                                                if div[0] == '{}'.format(num):
                                                    kcal_list.append(div)
                                            time.sleep(1)
                                            i5 = i1 - int(kcal_list[0][1]);i6 = i2 - int(kcal_list[0][2]);i7 = i3 - int(kcal_list[0][3]);i8 = i4 - int(kcal_list[0][4])
                                            print(f'\n|총 kcal: [{i5}kcal]\n|탄수화물: [{i6}kcal]\n|단백질: [{i7}kcal]\n|지방: [{i8}kcal]\n를 더 섭취하셔야 합니다.\n')

                                        if (i5 > 0):
                                            print()
                                            time.sleep(1)
                                            print('''
하루 권장 kcal보다 적은 kcal의 식단을 선택하셨습니다.
식사사이사이 먹을 수 있는 간식을 추천드립니다.
간식을 챙겨 드시기 바랍니다.

[추천 간식 목록]

|아몬드 10알 *총 kcal: [18kcal] 탄수화물: [9kcal] 단백질: [9kcal]
|바나나 1개 *총 kcal: [185kcal] 탄수화물: [160kcal] 단백질: [8kcal] 지방: [17kcal]
|삶은 달걀 2개 *총 kcal: [15kcal] 탄수화물: [8kcal] 단백질: [55kcal] 지방: [69kcal]
''')
                                        elif (i5 < 0):
                                            print()
                                            time.sleep(1)
                                            print('''
하루 권장 kcal보다 많은 kcal의 식단을 선택하셨습니다.
식사량을 조절하면서 드시는 것을 추천드립니다.''')
                                time.sleep(1)
                                print('맛있는 식사를 하세요.^-^')
                                break
                            elif 끼니 == 2:
                                time.sleep(1)
                                print(f'{name}님의 1끼 식사별 적정 kcal을 안내 해드립니다.\n|총 kcal:{round(a/3,0)}kcal\n|탄수화물: {round(a/3*0.5)}kcal\n|단백질: {round(a/3*0.3)}kcal\n|지방: {round(a/3*0.2)}kcal ')
                                for i in range(3):
                                    while True:
                                        try:
                                            time.sleep(1)
                                            menu = input('원하시는 종류를 선택해주세요. <한식: 1 입력, 양식: 2 입력, 일식: 3 입력>')
                                            time.sleep(1)
                                        except:
                                            print('1(한식) or 2(양식) or 3(일식) 으로 다시 입력해 주십시오.')
                                            return
                                        if menu == '1':
                                            self.korean()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 1:
                                                print(self.kor1+'를 선택하셨습니다.')
                                            elif num == 2:
                                                print(self.kor2+'를 선택하셨습니다.')
                                            elif num ==3:
                                                print(self.kor3+'를 선택하셨습니다.')
                                            elif num ==4:
                                                print(self.kor4+'를 선택하셨습니다.')
                                            elif num == 5:
                                                print(self.kor5+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        elif menu == '2':
                                            self.western()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 6:
                                                print(self.wes1+'를 선택하셨습니다.')
                                            elif num == 7:
                                                print(self.wes2+'를 선택하셨습니다.')
                                            elif num ==8:
                                                print(self.wes3+'를 선택하셨습니다.')
                                            elif num ==9:
                                                print(self.wes4+'를 선택하셨습니다.')
                                            elif num == 10:
                                                print(self.wes5+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        elif menu == '3':
                                            self.japanese()
                                            num = int(input('원하시는 메뉴의 번호를 입력해주세요. '))
                                            if num == 11:
                                                print(self.jap1+'를 선택하셨습니다.')
                                            elif num == 12:
                                                print(self.jap2+'를 선택하셨습니다.')
                                            elif num ==13:
                                                print(self.jap3+'를 선택하셨습니다.')
                                            elif num ==14:
                                                print(self.jap4+'를 선택하셨습니다.')
                                            else:
                                                print('다시 입력해주세요.')
                                                continue
                                            break
                                        else:
                                            print('1(한식) or 2(양식) or 3(일식) 으로 다시 입력해 주십시오.')

                                    if i == 0:
                                        filename = '칼로리표.csv'
                                        with open(filename,'r') as f:
                                            kcal_list = []
                                            while True:
                                                data = f.readline()
                                                if not data:
                                                    break
                                                div = data.split(',')
                                                if div[0] == '{}'.format(num):
                                                    kcal_list.append(div)
                                            time.sleep(1)
                                            i1 = int(a - int(kcal_list[0][1]));i2 = int(bcar - int(kcal_list[0][2]));i3 = int(bpro - int(kcal_list[0][3]));i4 = int(bfat - int(kcal_list[0][4]))
                                            print(f'\n|총 kcal: [{i1}kcal]\n|탄수화물: [{i2}kcal]\n|단백질: [{i3}kcal]\n|지방: [{i4}kcal]\n를 더 섭취하셔야 합니다.\n')

                                    elif i == 1:
                                        with open(filename,'r') as f:
                                            kcal_list = []
                                            while True:
                                                data = f.readline()
                                                if not data:
                                                    break
                                                div = data.split(',')
                                                if div[0] == '{}'.format(num):
                                                    kcal_list.append(div)
                                            time.sleep(1)
                                            i5 = i1 - int(kcal_list[0][1]);i6 = i2 - int(kcal_list[0][2]);i7 = i3 - int(kcal_list[0][3]);i8 = i4 - int(kcal_list[0][4])
                                            print(f'\n|총 kcal: [{i5}kcal]\n|탄수화물: [{i6}kcal]\n|단백질: [{i7}kcal]\n|지방: [{i8}kcal]\n를 더 섭취하셔야 합니다.\n')

                                    elif i == 2:
                                        with open(filename,'r') as f:
                                            kcal_list = []
                                            while True:
                                                data = f.readline()
                                                if not data:
                                                    break
                                                div = data.split(',')
                                                if div[0] == '{}'.format(num):
                                                    kcal_list.append(div)
                                            time.sleep(1)
                                            i9 = i5 - int(kcal_list[0][1]);i10 = i6 - int(kcal_list[0][2]);i11 = i7 - int(kcal_list[0][3]);i12 = i8 - int(kcal_list[0][4])
                                            print(f'\n|총 kcal: [{i9}kcal]\n|탄수화물: [{i10}kcal]\n|단백질: [{i11}kcal]\n|지방: [{i12}kcal]\n를 더 섭취하셔야 합니다.\n')

                                        if (i9 > 0):
                                            print()
                                            time.sleep(1)
                                            print('''
하루 권장 kcal보다 적은 kcal의 식단을 선택하셨습니다.
식사 사이사이 먹을 수 있는 간식을 추천드립니다.
간식을 챙겨 드시기 바랍니다.

[추천 간식 목록]

|아몬드 10알 *총 kcal: [18kcal] 탄수화물: [9kcal] 단백질: [9kcal]
|바나나 1개 *총 kcal: [185kcal] 탄수화물: [160kcal] 단백질: [8kcal] 지방: [17kcal]
|삶은 달걀 2개 *총 kcal: [15kcal] 탄수화물: [8kcal] 단백질: [55kcal] 지방: [69kcal]
''')
                                        elif (i9 < 0):
                                            print()
                                            time.sleep(1)
                                            print('''
하루 권장 kcal보다 많은 kcal의 식단을 선택하셨습니다.
식사량을 조절하면서 드시는 것을 추천드립니다.''')
                                time.sleep(1)
                                print('맛있는 식사를 하세요.^-^')
                                break
                            else:
                                print('1 or 2로 다시 입력해 주십시오.')
                                continue
                            
                            break
                        break
                    break
                break
            break
        
            


r = Recomendation()
r.person()
# Out:
# 사용하시는 분의 정보를 입력해주세요.
# 성함을 입력해주세요. 임희진
# 나이를 입력해주세요. 26
# 키를 입력해주세요. <cm 단위> 175
# 몸무게를 입력해주세요.<소수점 제외> 50
# 성별을 입력해주세요. <여자 or 남자> 여자
#
# 임희진님께서 입력해주신 정보는 아래와 같습니다.
#
# | 이름: 임희진님
# | 키: 175cm
# | 몸무게: 50kg
# | 성별: 여자
#
# 맞으면 1 입력, 다시 입력하시려면 2를 입력해주세요.
# 입력한 정보가 맞으면 기초대사량을 알려드립니다.1
#
# 임희진님의 기초 대사량은 746.0kcal입니다.
#
# *활동량이 적으면: 1 입력
# *활동량이 보통이면: 2 입력
# *활동량이 많으면: 3 입력  3
# 임희진님은 하루 2500kcal를 섭취해야 합니다.
#
# 다이어트 중이신가요? <y: 1 입력 or n: 2 입력> 1
# 다이어트 중이시면 탄수화물: 1250kcal, 단백질: 750kcal 지방: 500kcal를 섭취해야 합니다.
#
# 메뉴를 추천해드리겠습니다.
# 평소 몇 끼니를 드시나요? <2끼: 1 입력, 3끼: 2 입력>1
# 임희진님의 1끼 식사별 적정 kcal을 안내 해드립니다.
# |총 kcal:1250.0kcal
# |탄수화물: 625.0kcal
# |단백질: 375.0kcal
# |지방: 250.0kcal
# 원하시는 종류를 선택해주세요. <한식: 1 입력, 양식: 2 입력, 일식: 3 입력>1
#
# > 1. 현미밥, 데친 두부, 김치국, 계란말이, 배추김치
# --------------------------------------------------------------------
# 총 칼로리: [549kcal] 탄수화물: [254kcal] 단백질: [128kcal] 지방: [167kcal]
#
#
#
# > 2. 쌀밥, 갈치구이, 콩조림, 동치미
# ...
